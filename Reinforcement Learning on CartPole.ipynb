# %%
# https://stable-baselines3.readthedocs.io/en/master/guide/rl.html
# https://spinningup.openai.com/en/latest/spinningup/rl_intro2.html#a-taxonomy-of-rl-algorithms

# %% [markdown]
# # 1. Import Dependencies

# %%
# !pip install stable-baselines3[extra]
# Out:
# Process is interrupted.

# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Load Environment

# %%
ENV_NAME = 'CartPole-v0'
env = gym.make(ENV_NAME)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+= reward
        
    print(f'Episode: {episode} Score: {score}')
env.close()
# Out:
# Episode: 1 Score: 16.0
# Episode: 2 Score: 12.0
# Episode: 3 Score: 17.0
# Episode: 4 Score: 9.0
# Episode: 5 Score: 26.0

# %% [markdown]
# ## Understanding The Environment
#
# https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py

# %%
env.action_space # Always Check for choosing support Algorithm
# Out:
# Discrete(2)

# %%
# 0-push cart to left, 1-push cart to the right
env.action_space.sample()
# Out:
# 1

# %%
env.observation_space
# Out:
# Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)

# %%
# [cart position, cart velocity, pole angle, pole angular velocity]
env.observation_space.sample()
# Out:
# array([ 4.3913503e+00,  3.3374228e+38,  2.1033937e-01, -2.4968812e+37],
#       dtype=float32)

# %% [markdown]
# # 3. Train an RL Model

# %%
# Make your directory first
log_path = os.path.join('Training', 'Logs')

# %%
env = gym.make(ENV_NAME)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training/Logs/PPO_3
# -----------------------------
# | time/              |      |
# |    fps             | 800  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 560         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006706044 |
# |    clip_fraction        | 0.0378      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.555      |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 66          |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00239    |
# |    value_loss           | 104         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 505         |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.002254522 |
# |    clip_fraction        | 0.0136      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.557      |
# |    explained_variance   | 0.415       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 99          |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0019     |
# |    value_loss           | 113         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 4           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.005763363 |
# |    clip_fraction        | 0.00454     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.557      |
# |    explained_variance   | 0.163       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.9        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.000954   |
# |    value_loss           | 151         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 460          |
# |    iterations           | 5            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0041779904 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.541       |
# |    explained_variance   | 0.431        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.7         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00113     |
# |    value_loss           | 130          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 452         |
# |    iterations           | 6           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009995298 |
# |    clip_fraction        | 0.0805      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.535      |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.1        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00706    |
# |    value_loss           | 70.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 446          |
# |    iterations           | 7            |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0047880113 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.525       |
# |    explained_variance   | 0.324        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.5         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00172     |
# |    value_loss           | 160          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 436         |
# |    iterations           | 8           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009005031 |
# |    clip_fraction        | 0.0833      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.526      |
# |    explained_variance   | 0.55        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.9        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0063     |
# |    value_loss           | 136         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 433          |
# |    iterations           | 9            |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0015738254 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.528       |
# |    explained_variance   | 0.185        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.3         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00158     |
# |    value_loss           | 163          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 429         |
# |    iterations           | 10          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007510069 |
# |    clip_fraction        | 0.07        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.514      |
# |    explained_variance   | 0.435       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.9        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00475    |
# |    value_loss           | 138         |
# -----------------------------------------

# %% [markdown]
# # 4. Save and Reload Model

# %%
PPO_Path = os.path.join('Training', 'SavedModels', 'PPO_Model_CartPole')

# %%
model.save(PPO_Path)

# %%
del model

# %%
model = PPO.load(PPO_Path, env=env)

# %% [markdown]
# # 5. Evaluation

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# /home/brianadit24/Downloads/AI_Research/rlcourse_env/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (200.0, 0.0)

# %%
env.close()

# %% [markdown]
# # 6. Test Model

# %%
episodes = 20
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action, _ = model.predict(obs) # Change to our Agent
        obs, reward, done, info = env.step(action)
        score+= reward
    print(f'Episode: {episode} Score: {score}')
env.close()
# Out:
# Episode: 1 Score: [200.]
# Episode: 2 Score: [200.]
# Episode: 3 Score: [200.]
# Episode: 4 Score: [200.]
# Episode: 5 Score: [200.]
# Episode: 6 Score: [200.]
# Episode: 7 Score: [200.]
# Episode: 8 Score: [200.]
# Episode: 9 Score: [200.]
# Episode: 10 Score: [200.]
# Episode: 11 Score: [200.]
# Episode: 12 Score: [200.]
# Episode: 13 Score: [200.]
# Episode: 14 Score: [200.]
# Episode: 15 Score: [200.]
# Episode: 16 Score: [200.]
# Episode: 17 Score: [200.]
# Episode: 18 Score: [200.]
# Episode: 19 Score: [200.]
# Episode: 20 Score: [200.]

# %% [markdown]
# # 7. Viewing Logs in Tensorboard

# %%
training_log_path = os.path.join(log_path, 'PPO_3')

# %%
# !tensorboard --logdir={training_log_path}
# Out:
# TensorFlow installation not found - running with reduced feature set.
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.5.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %% [markdown]
# # 8. Adding a Callback to The Training Stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'SavedModels')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=200, verbose=1)
eval_callback = EvalCallback(env,
                            callback_on_new_best=stop_callback,
                            eval_freq=10000,
                            best_model_save_path=save_path,
                            verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=30000, callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 770  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 526          |
# |    iterations           | 2            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0025689472 |
# |    clip_fraction        | 0.0761       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | 0.000449     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.69         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0116      |
# |    value_loss           | 54.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 479          |
# |    iterations           | 3            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0046882913 |
# |    clip_fraction        | 0.0478       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.67        |
# |    explained_variance   | 0.0762       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.6         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0128      |
# |    value_loss           | 34.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 4           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011234288 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.248       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0202     |
# |    value_loss           | 51.9        |
# -----------------------------------------
# /home/brianadit24/Downloads/AI_Research/rlcourse_env/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 200

# %% [markdown]
# # 9. Changing Policies

# %%
net_arch = [dict(pi=[128,128,128,128], vf=[128,128,128,128])]

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path, policy_kwargs={'net_arch':net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=30000, callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_5
# -----------------------------
# | time/              |      |
# |    fps             | 429  |
# |    iterations      | 1    |
# |    time_elapsed    | 4    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017277732 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | -0.00328    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.28        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 16.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 3           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011552436 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.651      |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0317     |
# |    value_loss           | 23.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 4           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017143086 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.612      |
# |    explained_variance   | 0.562       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0288     |
# |    value_loss           | 33.6        |
# -----------------------------------------
# /home/brianadit24/Downloads/AI_Research/rlcourse_env/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=192.60 +/- 14.80
# Episode length: 192.60 +/- 14.80
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 193        |
# |    mean_reward          | 193        |
# | time/                   |            |
# |    fps                  | 234        |
# |    iterations           | 5          |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.00945996 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.581     |
# |    explained_variance   | 0.496      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 13.7       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0222    |
# |    value_loss           | 45.6       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 6           |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007556054 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.568      |
# |    explained_variance   | 0.652       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.6        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 35.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 7           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011686157 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.537      |
# |    explained_variance   | 0.738       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.7        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 33          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 8           |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007946594 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.529      |
# |    explained_variance   | 0.341       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.5        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00381    |
# |    value_loss           | 73          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 237          |
# |    iterations           | 9            |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0041202437 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.516       |
# |    explained_variance   | 0.246        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.6         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00199     |
# |    value_loss           | 106          |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    fps                  | 230         |
# |    iterations           | 10          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007179496 |
# |    clip_fraction        | 0.0628      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.494      |
# |    explained_variance   | 0.197       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.8        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00494    |
# |    value_loss           | 114         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 230          |
# |    iterations           | 11           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0056963935 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.478       |
# |    explained_variance   | 0.201        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63.6         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00182     |
# |    value_loss           | 114          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 232         |
# |    iterations           | 12          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008328085 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.469      |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64.2        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00356    |
# |    value_loss           | 144         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 13          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.006353268 |
# |    clip_fraction        | 0.0332      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.449      |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70.2        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00178    |
# |    value_loss           | 144         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 14          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.002480043 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.443      |
# |    explained_variance   | 0.333       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.6        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00189    |
# |    value_loss           | 153         |
# -----------------------------------------
# Eval num_timesteps=30000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 15           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0042480263 |
# |    clip_fraction        | 0.0502       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.439       |
# |    explained_variance   | 0.246        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 67           |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00337     |
# |    value_loss           | 163          |
# ------------------------------------------

# %% [markdown]
# # 10. Using an Alternate Algorithm

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=30000, callback=eval_callback)
# Out:
# Logging to Training/Logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.982    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1999     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 57       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.959    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 2700     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 130      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.935    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2880     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 206      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.912    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 3022     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 277      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.88     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 3008     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 379      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.851    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 3047     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 471      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.82     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 3175     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 569      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.787    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 3296     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 674      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.752    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 3352     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 782      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.712    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 3449     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 908      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.682    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 3501     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1003     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.66     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 3501     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1074     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.638    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 3514     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1142     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.613    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 3549     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1221     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.566    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 3577     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1372     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.537    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 3557     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1462     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.505    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 3428     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1564     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.478    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 3427     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1648     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.455    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 3419     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1721     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.422    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 3442     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1824     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.395    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 3437     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1912     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.367    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 3452     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.337    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 3428     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2095     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.302    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 3468     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2205     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.272    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 3484     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2298     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.248    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 3512     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2375     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.225    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 3502     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2448     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.198    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 3518     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2534     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.172    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 3535     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2616     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.131    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 3540     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.11     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 3524     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2812     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.0902   |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 3496     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2873     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.0668   |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 3506     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2947     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 3522     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3038     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 3563     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3208     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 3533     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3313     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 3521     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3401     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 3461     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3541     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 3414     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3599     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 3442     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3714     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 3417     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3803     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 3360     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3967     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 3317     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4052     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 3205     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4164     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 3170     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4248     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 3031     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4361     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 3048     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4448     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 3061     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4558     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 3070     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4652     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 3049     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4731     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 3052     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4835     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 3052     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4922     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 3054     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5004     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 3065     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5095     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 3070     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5184     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 3073     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 3081     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5318     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 3092     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5394     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 3110     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5504     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 3101     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5640     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 3110     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5712     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 3122     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5804     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 3131     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5882     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 3135     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 5937     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 3148     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 6033     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 3165     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 6144     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 3171     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 6228     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 3169     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 6320     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 3162     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 6416     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 3171     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 6503     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 3169     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 6551     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 3186     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 6676     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 3207     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 6818     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 3201     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 6896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 3209     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 6971     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 3203     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 7043     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 3208     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 7128     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 3212     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 7201     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 3216     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 7278     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 3226     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 7372     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 3247     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 7507     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 3258     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 7597     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 3277     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 7718     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 3288     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 7803     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 3306     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 7921     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 3311     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 8023     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 3320     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 8092     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 3338     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 8213     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 3351     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 8311     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 3357     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 8385     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 3367     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 8486     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 3380     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 8631     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 3392     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 8731     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 3402     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 8841     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 3409     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 8915     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 3420     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 9046     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 3429     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 9133     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 3432     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 9219     |
# ----------------------------------
# Eval num_timesteps=9280, episode_reward=9.20 +/- 0.98
# Episode length: 9.20 +/- 0.98
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9.2      |
# |    mean_reward      | 9.2      |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 3372     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 9307     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 3375     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 9396     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 3378     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 9456     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 3377     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 9507     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 3390     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 9637     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 3404     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 9755     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 3418     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 9881     |
# ----------------------------------
# /home/brianadit24/Downloads/AI_Research/rlcourse_env/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 3419     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 9958     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 3384     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 10056    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 3394     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 10151    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 3407     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 10286    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 3419     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 10424    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 3428     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 10522    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 3436     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 10626    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 3443     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 10710    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 3458     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 10856    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 3469     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 10967    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 3474     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 11071    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 3480     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 11158    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 3481     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 11220    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 3484     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 11311    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 3490     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 11409    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 3496     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 11512    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 3502     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 11587    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 3503     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 11664    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 3511     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 11775    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 3516     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 11886    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 3522     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 11965    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 3527     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 12050    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 3534     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 12150    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 3542     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 12264    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 3549     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 12355    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 3555     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 12464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 3565     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 12583    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 3572     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 12695    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 3575     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 12776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 3579     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 12842    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 3585     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 12958    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 3589     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 13028    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 3594     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 13111    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 3600     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 13207    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 3606     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 13309    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 3619     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 13463    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 3628     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 13589    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 3628     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 13665    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 3626     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 13719    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 3631     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 13816    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 3635     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 13892    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 3640     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 13982    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 3643     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 14069    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 3653     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 14220    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 3658     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 14339    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# ...
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1088     |
# |    fps              | 3851     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 25386    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1092     |
# |    fps              | 3852     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 25506    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1096     |
# |    fps              | 3854     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 25642    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 3855     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 25713    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1104     |
# |    fps              | 3855     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 25781    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1108     |
# |    fps              | 3856     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 25867    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1112     |
# |    fps              | 3856     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 25927    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1116     |
# |    fps              | 3858     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 26043    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 3859     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 26181    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1124     |
# |    fps              | 3859     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 26288    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1128     |
# |    fps              | 3860     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 26395    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1132     |
# |    fps              | 3859     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 26477    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1136     |
# |    fps              | 3858     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 26556    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1140     |
# |    fps              | 3858     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 26632    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1144     |
# |    fps              | 3856     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 26687    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1148     |
# |    fps              | 3856     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 26789    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1152     |
# |    fps              | 3855     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 26867    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1156     |
# |    fps              | 3855     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 26928    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1160     |
# |    fps              | 3854     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 27014    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1164     |
# |    fps              | 3853     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 27118    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1168     |
# |    fps              | 3853     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 27198    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1172     |
# |    fps              | 3853     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 27269    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1176     |
# |    fps              | 3844     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 27342    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1180     |
# |    fps              | 3843     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 27411    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1184     |
# |    fps              | 3846     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 27531    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1188     |
# |    fps              | 3846     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 27612    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1192     |
# |    fps              | 3848     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 27679    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1196     |
# |    fps              | 3853     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 27839    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 3855     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 27937    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1204     |
# |    fps              | 3854     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 28043    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1208     |
# |    fps              | 3848     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 28130    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1212     |
# |    fps              | 3838     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 28209    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1216     |
# |    fps              | 3836     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 28337    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1220     |
# |    fps              | 3835     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 28418    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1224     |
# |    fps              | 3830     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 28537    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1228     |
# |    fps              | 3824     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 28646    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1232     |
# |    fps              | 3823     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 28753    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1236     |
# |    fps              | 3822     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 28846    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1240     |
# |    fps              | 3814     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 28920    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1244     |
# |    fps              | 3812     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 29004    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1248     |
# |    fps              | 3809     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 29070    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1252     |
# |    fps              | 3808     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 29167    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1256     |
# |    fps              | 3808     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 29253    |
# ----------------------------------
# Eval num_timesteps=29280, episode_reward=9.20 +/- 0.75
# Episode length: 9.20 +/- 0.75
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9.2      |
# |    mean_reward      | 9.2      |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1260     |
# |    fps              | 3794     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 29360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1264     |
# |    fps              | 3795     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 29445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1268     |
# |    fps              | 3796     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 29531    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1272     |
# |    fps              | 3795     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 29595    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1276     |
# |    fps              | 3796     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 29714    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1280     |
# |    fps              | 3796     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 29810    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 1284     |
# |    fps              | 3794     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 29911    |
# ----------------------------------

# %%
dqn_path = os.path.join('Training', 'Saved Models', 'DQN_model')

# %%
model.save(dqn_path)

# %%
model = DQN.load(dqn_path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)

# %%
env.close()
